# %%
from autogen_ext.models.ollama import OllamaChatCompletionClient

model_client = OllamaChatCompletionClient(
    model="qwen2.5:7b",
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from autogen_ext.models.ollama import OllamaChatCompletionClient
#       3 model_client = OllamaChatCompletionClient(
#       4     model="qwen2.5:7b",
#       5 )
#
# ModuleNotFoundError: No module named 'autogen_ext.models'

# %%
pip install "autogen-ext[ollama]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: autogen-ext 0.0.1 does not provide the extra 'ollama'
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall autogen-ext autogen pyautogen -y
# Out:
# Found existing installation: autogen-ext 0.0.1
# Uninstalling autogen-ext-0.0.1:
#   Successfully uninstalled autogen-ext-0.0.1
# WARNING: Skipping autogen as it is not installed.
# WARNING: Skipping pyautogen as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U autogen-agentchat
pip install -U autogen-ext
# Out:
#   Cell In[5], line 1
#     pip install -U autogen-agentchat
#         ^
# SyntaxError: invalid syntax

# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# /Library/Developer/CommandLineTools/usr/bin/python3
# 3.9.6 (default, Apr 17 2026, 18:15:52)
# [Clang 21.0.0 (clang-2100.1.1.101)]

# %%
import autogen_agentchat

print(autogen_agentchat.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import autogen_agentchat
#       3 print(autogen_agentchat.__version__)
#
# ModuleNotFoundError: No module named 'autogen_agentchat'

# %%
python3 -m pip show autogen-agentchat
# Out:
#   Cell In[8], line 1
#     python3 -m pip show autogen-agentchat
#                ^
# SyntaxError: invalid syntax

# %%
import sys
print(sys.executable)
# Out:
# /Library/Developer/CommandLineTools/usr/bin/python3

# %%
import autogen

config_list = [
    {
        "model": "qwen2.5:7b",
        "base_url": "http://localhost:11434/v1",
        "api_key": "ollama",
    }
]

assistant = autogen.AssistantAgent(
    name="assistant",
    llm_config={"config_list": config_list}
)

# %%
import autogen

config_list = [
    {
        "model": "qwen2.5:7b",
        "base_url": "http://localhost:11434/v1",
        "api_key": "ollama",
    }
]

assistant = autogen.AssistantAgent(
    name="assistant",
    llm_config={"config_list": config_list}
)

user_proxy = autogen.UserProxyAgent(
    name="user",
    human_input_mode="NEVER",
    max_consecutive_auto_reply=1,
    code_execution_config=False
)

user_proxy.initiate_chat(
    assistant,
    message="What is machine learning?"
)
# Out:
# user (to assistant):
#
# What is machine learning?
#
# --------------------------------------------------------------------------------
# assistant (to user):
#
# To explain what machine learning is, I will first define it and provide some examples, then I will use a simple Python code snippet to demonstrate a basic concept of machine learning.
#
# Machine Learning (ML) is a subset of artificial intelligence that involves training algorithms on data so they can learn from the data and make predictions or decisions without being explicitly programmed. It enables machines to identify patterns and relationships within the data and improve their performance as they learn from more data.
#
# Here's a simple example using Python code to train a machine learning model that predicts whether an email is spam or not based on certain features:
#
# ```python
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
#
# ...

# %%
import autogen

assistant = autogen.AssistantAgent(...)
user_proxy = autogen.UserProxyAgent(...)

# %%
import autogen

config_list = [
    {
        "model": "qwen2.5:7b",
        "base_url": "http://localhost:11434/v1",
        "api_key": "ollama",
    }
]

assistant = autogen.AssistantAgent(
    name="airline_agent",
    system_message="You are a helpful assistant for an airline. You give short, humorous answers.",
    llm_config={"config_list": config_list}
)

# %%
chat_result = user_proxy.initiate_chat(
    assistant,
    message="I'd like to go to London"
)

print(chat_result)
# Out:
# Ellipsis (to airline_agent):
#
# I'd like to go to London
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 chat_result = user_proxy.initiate_chat(
#       2     assistant,
#       3     message="I'd like to go to London"
#       4 )
#       6 print(chat_result)
#
# File ~/Library/Python/3.9/lib/python/site-packages/autogen/agentchat/conversable_agent.py:1115, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1113     else:
#    1114         msg2send = self.generate_init_message(message, **kwargs)
# -> 1115     self.send(msg2send, recipient, silent=silent)
#    1116 summary = self._summarize_chat(
#    1117     summary_method,
#    1118     summary_args,
# ...

# %%
print(type(user_proxy))
print(user_proxy)
# Out:
# <class 'autogen.agentchat.user_proxy_agent.UserProxyAgent'>
# ...

# %%
print(type(assistant))
print(assistant.name)
# Out:
# <class 'autogen.agentchat.assistant_agent.AssistantAgent'>
# airline_agent
